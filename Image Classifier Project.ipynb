# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from PIL import Image

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz).

# %% [markdown]
# If you do not find the `flowers/` dataset in the current directory, **/workspace/home/aipnd-project/**, you can download it using the following commands.
#
# ```bash
# !wget 'https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz'
# !unlink flowers
# !mkdir flowers && tar -xzf flower_data.tar.gz -C flowers
# ```

# %% [markdown]
# ## Data Description
# The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets

train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                                                            [0.229, 0.224, 0.225])])

test_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])
valid_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])

# TODO: Load the datasets with ImageFolder
train_dataset = datasets.ImageFolder(train_dir, transform = train_transforms)
valid_dataset = datasets.ImageFolder(valid_dir, transform = valid_transforms)
test_dataset = datasets.ImageFolder(test_dir, transform = test_transforms)


# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
validloader = torch.utils.data.DataLoader(valid_dataset, batch_size=32, shuffle=True)
testloader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# ## Note for Workspace users:
# If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# choose a model

def model_setup(name = 'densenet121'):
    if name == 'vgg16':
        model = models.vgg16(pretrained = True)
        first_layer = 25088
    elif name == 'densenet121':
        model = models.densenet121(pretrained = True)
        first_layer = 1024
    elif name == 'alexnet':
        model = models.alexnet(pretrained = True)
        first_layer = 9216

    return model, first_layer

# %%
# TODO: Build and train your network

model, first_layer = model_setup()

for param in model.parameters():
    param.requires_grad = False
    
model.classifier = nn.Sequential(nn.Linear(first_layer, 256),
                                 nn.ReLU(),
                                 nn.Dropout(0.2),
                                 nn.Linear(256, 90),
                                 nn.ReLU(),
                                 nn.Linear(90, 80),
                                 nn.ReLU(),
                                 nn.Linear(80, 102),
                                 nn.LogSoftmax(dim=1))

criterion = nn.NLLLoss()

optimizer = optim.Adam(model.classifier.parameters(), lr=0.003)
model.cuda()


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = "cpu"
print(device)


model.to(device)


epochs = 12
steps = 0
running_loss = 0
print_every = 5
for epoch in range(epochs):
    running_loss = 0
    for inputs, labels in trainloader:
        inputs,labels = inputs.to(device), labels.to(device)

        steps += 1
        
        #print("Before model.forward in epoch:",epoch)
        logps = model.forward(inputs)
        #print("Before criterion in epoch:",epoch)
        loss = criterion(logps, labels)
     
        #print("optimizer in epoch:",epoch)
        optimizer.zero_grad()
        #print("Before loss backward in epoch:",epoch)
        loss.backward()
        #print("Before optimizer.step in epoch:",epoch)

        optimizer.step()
        running_loss += loss.item()
        
        if steps % print_every == 0:
            test_loss = 0
            accuracy = 0
            model.eval()
            with torch.no_grad():
                for inputs, labels in validloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    logps = model.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    
                    test_loss += batch_loss.item()
                    
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                    
            print(f"Epoch {epoch+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Valid loss: {test_loss/len(validloader):.3f}.. "
                  f"Valid accuracy: {accuracy/len(validloader):.3f}")
            running_loss = 0
            model.train()
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /home/student/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 99.9MB/s]
# cuda
# Epoch 1/12.. Train loss: 4.630.. Valid loss: 4.597.. Valid accuracy: 0.031
# Epoch 1/12.. Train loss: 4.632.. Valid loss: 4.590.. Valid accuracy: 0.036
# Epoch 1/12.. Train loss: 4.606.. Valid loss: 4.554.. Valid accuracy: 0.050
# Epoch 1/12.. Train loss: 4.491.. Valid loss: 4.536.. Valid accuracy: 0.026
# Epoch 1/12.. Train loss: 4.612.. Valid loss: 4.492.. Valid accuracy: 0.025
# Epoch 1/12.. Train loss: 4.494.. Valid loss: 4.484.. Valid accuracy: 0.048
# Epoch 1/12.. Train loss: 4.457.. Valid loss: 4.445.. Valid accuracy: 0.042
# Epoch 1/12.. Train loss: 4.482.. Valid loss: 4.394.. Valid accuracy: 0.067
# Epoch 1/12.. Train loss: 4.363.. Valid loss: 4.330.. Valid accuracy: 0.064
# Epoch 1/12.. Train loss: 4.173.. Valid loss: 4.295.. Valid accuracy: 0.071
# Epoch 1/12.. Train loss: 4.401.. Valid loss: 4.232.. Valid accuracy: 0.081
# Epoch 1/12.. Train loss: 4.302.. Valid loss: 4.164.. Valid accuracy: 0.063
# Epoch 1/12.. Train loss: 4.132.. Valid loss: 4.085.. Valid accuracy: 0.077
# Epoch 1/12.. Train loss: 4.303.. Valid loss: 4.044.. Valid accuracy: 0.106
# Epoch 1/12.. Train loss: 4.089.. Valid loss: 3.948.. Valid accuracy: 0.115
# Epoch 1/12.. Train loss: 3.939.. Valid loss: 3.875.. Valid accuracy: 0.121
# Epoch 1/12.. Train loss: 4.210.. Valid loss: 3.819.. Valid accuracy: 0.107
# Epoch 1/12.. Train loss: 3.937.. Valid loss: 3.765.. Valid accuracy: 0.129
# Epoch 1/12.. Train loss: 3.969.. Valid loss: 3.657.. Valid accuracy: 0.130
# Epoch 1/12.. Train loss: 3.854.. Valid loss: 3.606.. Valid accuracy: 0.114
# Epoch 1/12.. Train loss: 3.832.. Valid loss: 3.565.. Valid accuracy: 0.114
# Epoch 1/12.. Train loss: 3.760.. Valid loss: 3.456.. Valid accuracy: 0.132
# Epoch 1/12.. Train loss: 3.725.. Valid loss: 3.387.. Valid accuracy: 0.139
# Epoch 1/12.. Train loss: 3.554.. Valid loss: 3.339.. Valid accuracy: 0.167
# Epoch 1/12.. Train loss: 3.512.. Valid loss: 3.292.. Valid accuracy: 0.189
# Epoch 1/12.. Train loss: 3.512.. Valid loss: 3.146.. Valid accuracy: 0.216
# Epoch 1/12.. Train loss: 3.379.. Valid loss: 3.076.. Valid accuracy: 0.222
# Epoch 1/12.. Train loss: 3.572.. Valid loss: 3.265.. Valid accuracy: 0.157
# Epoch 1/12.. Train loss: 3.461.. Valid loss: 3.050.. Valid accuracy: 0.205
# Epoch 1/12.. Train loss: 3.245.. Valid loss: 3.101.. Valid accuracy: 0.204
# Epoch 1/12.. Train loss: 3.330.. Valid loss: 3.146.. Valid accuracy: 0.195
# Epoch 1/12.. Train loss: 3.384.. Valid loss: 2.980.. Valid accuracy: 0.227
# Epoch 1/12.. Train loss: 3.262.. Valid loss: 2.878.. Valid accuracy: 0.270
# Epoch 1/12.. Train loss: 3.255.. Valid loss: 2.874.. Valid accuracy: 0.259
# Epoch 1/12.. Train loss: 3.054.. Valid loss: 2.771.. Valid accuracy: 0.252
# Epoch 1/12.. Train loss: 3.022.. Valid loss: 2.767.. Valid accuracy: 0.267
# Epoch 1/12.. Train loss: 2.899.. Valid loss: 2.695.. Valid accuracy: 0.285
# Epoch 1/12.. Train loss: 2.892.. Valid loss: 2.579.. Valid accuracy: 0.330
# Epoch 1/12.. Train loss: 2.662.. Valid loss: 2.530.. Valid accuracy: 0.308
# Epoch 1/12.. Train loss: 2.821.. Valid loss: 2.527.. Valid accuracy: 0.308
# Epoch 1/12.. Train loss: 2.896.. Valid loss: 2.515.. Valid accuracy: 0.306
# Epoch 2/12.. Train loss: 2.823.. Valid loss: 2.519.. Valid accuracy: 0.322
# Epoch 2/12.. Train loss: 2.865.. Valid loss: 2.487.. Valid accuracy: 0.343
# Epoch 2/12.. Train loss: 2.930.. Valid loss: 2.417.. Valid accuracy: 0.365
# Epoch 2/12.. Train loss: 2.870.. Valid loss: 2.483.. Valid accuracy: 0.363
# Epoch 2/12.. Train loss: 2.754.. Valid loss: 2.382.. Valid accuracy: 0.357
# Epoch 2/12.. Train loss: 2.755.. Valid loss: 2.422.. Valid accuracy: 0.351
# Epoch 2/12.. Train loss: 2.763.. Valid loss: 2.302.. Valid accuracy: 0.382
# Epoch 2/12.. Train loss: 2.805.. Valid loss: 2.373.. Valid accuracy: 0.338
# Epoch 2/12.. Train loss: 2.634.. Valid loss: 2.419.. Valid accuracy: 0.331
# Epoch 2/12.. Train loss: 2.614.. Valid loss: 2.260.. Valid accuracy: 0.373
# Epoch 2/12.. Train loss: 2.749.. Valid loss: 2.279.. Valid accuracy: 0.353
# Epoch 2/12.. Train loss: 2.891.. Valid loss: 2.319.. Valid accuracy: 0.336
# Epoch 2/12.. Train loss: 2.953.. Valid loss: 2.293.. Valid accuracy: 0.378
# Epoch 2/12.. Train loss: 2.697.. Valid loss: 2.291.. Valid accuracy: 0.368
# Epoch 2/12.. Train loss: 2.484.. Valid loss: 2.124.. Valid accuracy: 0.426
# Epoch 2/12.. Train loss: 2.513.. Valid loss: 2.238.. Valid accuracy: 0.385
# Epoch 2/12.. Train loss: 2.498.. Valid loss: 2.126.. Valid accuracy: 0.403
# Epoch 2/12.. Train loss: 2.486.. Valid loss: 2.059.. Valid accuracy: 0.422
# Epoch 2/12.. Train loss: 2.358.. Valid loss: 2.425.. Valid accuracy: 0.363
# Epoch 2/12.. Train loss: 2.519.. Valid loss: 2.243.. Valid accuracy: 0.334
# Epoch 2/12.. Train loss: 2.558.. Valid loss: 2.172.. Valid accuracy: 0.388
# Epoch 2/12.. Train loss: 2.748.. Valid loss: 2.202.. Valid accuracy: 0.397
# Epoch 2/12.. Train loss: 2.462.. Valid loss: 2.139.. Valid accuracy: 0.378
# Epoch 2/12.. Train loss: 2.647.. Valid loss: 2.241.. Valid accuracy: 0.392
# Epoch 2/12.. Train loss: 2.441.. Valid loss: 2.229.. Valid accuracy: 0.375
# Epoch 2/12.. Train loss: 2.576.. Valid loss: 2.114.. Valid accuracy: 0.418
# Epoch 2/12.. Train loss: 2.217.. Valid loss: 2.096.. Valid accuracy: 0.426
# Epoch 2/12.. Train loss: 2.427.. Valid loss: 1.925.. Valid accuracy: 0.470
# Epoch 2/12.. Train loss: 2.265.. Valid loss: 1.874.. Valid accuracy: 0.481
# Epoch 2/12.. Train loss: 2.354.. Valid loss: 1.846.. Valid accuracy: 0.484
# Epoch 2/12.. Train loss: 2.312.. Valid loss: 1.896.. Valid accuracy: 0.477
# Epoch 2/12.. Train loss: 2.335.. Valid loss: 1.902.. Valid accuracy: 0.473
# Epoch 2/12.. Train loss: 2.182.. Valid loss: 1.897.. Valid accuracy: 0.444
# Epoch 2/12.. Train loss: 2.328.. Valid loss: 1.849.. Valid accuracy: 0.465
# Epoch 2/12.. Train loss: 2.282.. Valid loss: 1.835.. Valid accuracy: 0.475
# Epoch 2/12.. Train loss: 2.370.. Valid loss: 1.876.. Valid accuracy: 0.458
# Epoch 2/12.. Train loss: 2.483.. Valid loss: 1.795.. Valid accuracy: 0.467
# Epoch 2/12.. Train loss: 2.443.. Valid loss: 1.800.. Valid accuracy: 0.496
# Epoch 2/12.. Train loss: 2.075.. Valid loss: 1.707.. Valid accuracy: 0.532
# Epoch 2/12.. Train loss: 2.079.. Valid loss: 1.610.. Valid accuracy: 0.541
# Epoch 2/12.. Train loss: 2.092.. Valid loss: 1.716.. Valid accuracy: 0.525
# Epoch 3/12.. Train loss: 1.832.. Valid loss: 1.724.. Valid accuracy: 0.514
# Epoch 3/12.. Train loss: 2.360.. Valid loss: 1.713.. Valid accuracy: 0.507
# Epoch 3/12.. Train loss: 1.963.. Valid loss: 1.709.. Valid accuracy: 0.534
# Epoch 3/12.. Train loss: 2.059.. Valid loss: 1.732.. Valid accuracy: 0.516
# Epoch 3/12.. Train loss: 2.360.. Valid loss: 1.720.. Valid accuracy: 0.489
# Epoch 3/12.. Train loss: 2.244.. Valid loss: 1.743.. Valid accuracy: 0.501
# Epoch 3/12.. Train loss: 2.090.. Valid loss: 1.762.. Valid accuracy: 0.501
# Epoch 3/12.. Train loss: 2.340.. Valid loss: 1.673.. Valid accuracy: 0.525
# Epoch 3/12.. Train loss: 2.278.. Valid loss: 1.627.. Valid accuracy: 0.533
# Epoch 3/12.. Train loss: 2.283.. Valid loss: 1.566.. Valid accuracy: 0.551
# Epoch 3/12.. Train loss: 1.977.. Valid loss: 1.551.. Valid accuracy: 0.554
# Epoch 3/12.. Train loss: 1.937.. Valid loss: 1.505.. Valid accuracy: 0.588
# Epoch 3/12.. Train loss: 1.956.. Valid loss: 1.623.. Valid accuracy: 0.535
# Epoch 3/12.. Train loss: 2.049.. Valid loss: 1.582.. Valid accuracy: 0.547
# Epoch 3/12.. Train loss: 1.905.. Valid loss: 1.543.. Valid accuracy: 0.554
# Epoch 3/12.. Train loss: 2.324.. Valid loss: 1.597.. Valid accuracy: 0.542
# Epoch 3/12.. Train loss: 1.992.. Valid loss: 1.563.. Valid accuracy: 0.539
# Epoch 3/12.. Train loss: 1.728.. Valid loss: 1.478.. Valid accuracy: 0.570
# Epoch 3/12.. Train loss: 1.802.. Valid loss: 1.533.. Valid accuracy: 0.557
# Epoch 3/12.. Train loss: 2.016.. Valid loss: 1.462.. Valid accuracy: 0.579
# Epoch 3/12.. Train loss: 1.949.. Valid loss: 1.515.. Valid accuracy: 0.551
# Epoch 3/12.. Train loss: 1.960.. Valid loss: 1.502.. Valid accuracy: 0.554
# Epoch 3/12.. Train loss: 1.913.. Valid loss: 1.453.. Valid accuracy: 0.558
# Epoch 3/12.. Train loss: 2.007.. Valid loss: 1.394.. Valid accuracy: 0.612
# Epoch 3/12.. Train loss: 2.069.. Valid loss: 1.492.. Valid accuracy: 0.579
# Epoch 3/12.. Train loss: 1.742.. Valid loss: 1.326.. Valid accuracy: 0.614
# Epoch 3/12.. Train loss: 1.935.. Valid loss: 1.446.. Valid accuracy: 0.583
# Epoch 3/12.. Train loss: 1.903.. Valid loss: 1.545.. Valid accuracy: 0.536
# Epoch 3/12.. Train loss: 1.943.. Valid loss: 1.487.. Valid accuracy: 0.560
# Epoch 3/12.. Train loss: 1.987.. Valid loss: 1.540.. Valid accuracy: 0.567
# Epoch 3/12.. Train loss: 2.019.. Valid loss: 1.654.. Valid accuracy: 0.534
# Epoch 3/12.. Train loss: 1.963.. Valid loss: 1.446.. Valid accuracy: 0.590
# Epoch 3/12.. Train loss: 1.943.. Valid loss: 1.353.. Valid accuracy: 0.607
# Epoch 3/12.. Train loss: 1.934.. Valid loss: 1.453.. Valid accuracy: 0.590
# Epoch 3/12.. Train loss: 1.915.. Valid loss: 1.438.. Valid accuracy: 0.572
# Epoch 3/12.. Train loss: 1.929.. Valid loss: 1.507.. Valid accuracy: 0.570
# Epoch 3/12.. Train loss: 1.773.. Valid loss: 1.349.. Valid accuracy: 0.602
# Epoch 3/12.. Train loss: 1.852.. Valid loss: 1.425.. Valid accuracy: 0.579
# Epoch 3/12.. Train loss: 1.691.. Valid loss: 1.377.. Valid accuracy: 0.589
# Epoch 3/12.. Train loss: 1.981.. Valid loss: 1.396.. Valid accuracy: 0.572
# Epoch 3/12.. Train loss: 1.740.. Valid loss: 1.465.. Valid accuracy: 0.567
# Epoch 4/12.. Train loss: 1.681.. Valid loss: 1.329.. Valid accuracy: 0.607
# Epoch 4/12.. Train loss: 1.914.. Valid loss: 1.304.. Valid accuracy: 0.608
# Epoch 4/12.. Train loss: 2.115.. Valid loss: 1.455.. Valid accuracy: 0.568
# Epoch 4/12.. Train loss: 1.703.. Valid loss: 1.365.. Valid accuracy: 0.605
# Epoch 4/12.. Train loss: 1.807.. Valid loss: 1.319.. Valid accuracy: 0.624
# Epoch 4/12.. Train loss: 1.838.. Valid loss: 1.348.. Valid accuracy: 0.596
# Epoch 4/12.. Train loss: 1.811.. Valid loss: 1.398.. Valid accuracy: 0.584
# Epoch 4/12.. Train loss: 1.728.. Valid loss: 1.292.. Valid accuracy: 0.637
# Epoch 4/12.. Train loss: 1.713.. Valid loss: 1.244.. Valid accuracy: 0.640
# Epoch 4/12.. Train loss: 1.842.. Valid loss: 1.391.. Valid accuracy: 0.595
# Epoch 4/12.. Train loss: 1.948.. Valid loss: 1.356.. Valid accuracy: 0.601
# Epoch 4/12.. Train loss: 1.869.. Valid loss: 1.372.. Valid accuracy: 0.621
# Epoch 4/12.. Train loss: 1.807.. Valid loss: 1.327.. Valid accuracy: 0.616
# Epoch 4/12.. Train loss: 1.727.. Valid loss: 1.318.. Valid accuracy: 0.607
# Epoch 4/12.. Train loss: 1.761.. Valid loss: 1.229.. Valid accuracy: 0.640
# Epoch 4/12.. Train loss: 1.942.. Valid loss: 1.325.. Valid accuracy: 0.614
# Epoch 4/12.. Train loss: 1.654.. Valid loss: 1.308.. Valid accuracy: 0.614
# Epoch 4/12.. Train loss: 1.863.. Valid loss: 1.247.. Valid accuracy: 0.628
# Epoch 4/12.. Train loss: 1.736.. Valid loss: 1.236.. Valid accuracy: 0.636
# Epoch 4/12.. Train loss: 1.900.. Valid loss: 1.274.. Valid accuracy: 0.617
# Epoch 4/12.. Train loss: 1.749.. Valid loss: 1.237.. Valid accuracy: 0.637
# Epoch 4/12.. Train loss: 1.941.. Valid loss: 1.159.. Valid accuracy: 0.662
# Epoch 4/12.. Train loss: 1.670.. Valid loss: 1.258.. Valid accuracy: 0.622
# Epoch 4/12.. Train loss: 1.632.. Valid loss: 1.338.. Valid accuracy: 0.597
# Epoch 4/12.. Train loss: 1.853.. Valid loss: 1.319.. Valid accuracy: 0.615
# Epoch 4/12.. Train loss: 1.778.. Valid loss: 1.192.. Valid accuracy: 0.654
# Epoch 4/12.. Train loss: 1.795.. Valid loss: 1.296.. Valid accuracy: 0.621
# Epoch 4/12.. Train loss: 1.989.. Valid loss: 1.172.. Valid accuracy: 0.662
# Epoch 4/12.. Train loss: 1.525.. Valid loss: 1.176.. Valid accuracy: 0.653
# Epoch 4/12.. Train loss: 1.863.. Valid loss: 1.194.. Valid accuracy: 0.653
# Epoch 4/12.. Train loss: 1.789.. Valid loss: 1.226.. Valid accuracy: 0.638
# Epoch 4/12.. Train loss: 1.614.. Valid loss: 1.283.. Valid accuracy: 0.613
# Epoch 4/12.. Train loss: 2.014.. Valid loss: 1.190.. Valid accuracy: 0.649
# Epoch 4/12.. Train loss: 1.820.. Valid loss: 1.197.. Valid accuracy: 0.637
# Epoch 4/12.. Train loss: 1.632.. Valid loss: 1.365.. Valid accuracy: 0.605
# Epoch 4/12.. Train loss: 2.074.. Valid loss: 1.215.. Valid accuracy: 0.627
# Epoch 4/12.. Train loss: 1.901.. Valid loss: 1.159.. Valid accuracy: 0.646
# Epoch 4/12.. Train loss: 1.993.. Valid loss: 1.139.. Valid accuracy: 0.677
# Epoch 4/12.. Train loss: 1.694.. Valid loss: 1.215.. Valid accuracy: 0.628
# Epoch 4/12.. Train loss: 1.771.. Valid loss: 1.276.. Valid accuracy: 0.614
# Epoch 4/12.. Train loss: 1.783.. Valid loss: 1.180.. Valid accuracy: 0.656
# Epoch 5/12.. Train loss: 1.660.. Valid loss: 1.221.. Valid accuracy: 0.648
# Epoch 5/12.. Train loss: 1.744.. Valid loss: 1.121.. Valid accuracy: 0.652
# Epoch 5/12.. Train loss: 1.792.. Valid loss: 1.096.. Valid accuracy: 0.669
# Epoch 5/12.. Train loss: 1.740.. Valid loss: 1.066.. Valid accuracy: 0.708
# Epoch 5/12.. Train loss: 1.848.. Valid loss: 1.018.. Valid accuracy: 0.705
# Epoch 5/12.. Train loss: 1.445.. Valid loss: 1.042.. Valid accuracy: 0.707
# Epoch 5/12.. Train loss: 1.507.. Valid loss: 1.149.. Valid accuracy: 0.650
# Epoch 5/12.. Train loss: 1.736.. Valid loss: 1.121.. Valid accuracy: 0.659
# Epoch 5/12.. Train loss: 1.571.. Valid loss: 1.178.. Valid accuracy: 0.652
# Epoch 5/12.. Train loss: 1.731.. Valid loss: 1.228.. Valid accuracy: 0.625
# Epoch 5/12.. Train loss: 1.683.. Valid loss: 1.337.. Valid accuracy: 0.622
# Epoch 5/12.. Train loss: 1.729.. Valid loss: 1.231.. Valid accuracy: 0.647
# Epoch 5/12.. Train loss: 1.499.. Valid loss: 1.162.. Valid accuracy: 0.675
# Epoch 5/12.. Train loss: 1.666.. Valid loss: 1.126.. Valid accuracy: 0.663
# Epoch 5/12.. Train loss: 1.570.. Valid loss: 1.275.. Valid accuracy: 0.636
# Epoch 5/12.. Train loss: 1.706.. Valid loss: 1.115.. Valid accuracy: 0.667
# Epoch 5/12.. Train loss: 1.883.. Valid loss: 1.090.. Valid accuracy: 0.677
# Epoch 5/12.. Train loss: 1.578.. Valid loss: 1.159.. Valid accuracy: 0.658
# Epoch 5/12.. Train loss: 1.591.. Valid loss: 1.077.. Valid accuracy: 0.673
# Epoch 5/12.. Train loss: 1.947.. Valid loss: 1.082.. Valid accuracy: 0.685
# Epoch 5/12.. Train loss: 1.736.. Valid loss: 1.102.. Valid accuracy: 0.664
# Epoch 5/12.. Train loss: 1.566.. Valid loss: 1.080.. Valid accuracy: 0.688
# Epoch 5/12.. Train loss: 1.690.. Valid loss: 1.122.. Valid accuracy: 0.669
# Epoch 5/12.. Train loss: 1.523.. Valid loss: 1.038.. Valid accuracy: 0.702
# Epoch 5/12.. Train loss: 1.568.. Valid loss: 1.009.. Valid accuracy: 0.720
# Epoch 5/12.. Train loss: 1.471.. Valid loss: 1.064.. Valid accuracy: 0.695
# Epoch 5/12.. Train loss: 1.366.. Valid loss: 1.131.. Valid accuracy: 0.676
# Epoch 5/12.. Train loss: 1.704.. Valid loss: 1.023.. Valid accuracy: 0.688
# Epoch 5/12.. Train loss: 1.354.. Valid loss: 0.987.. Valid accuracy: 0.710
# Epoch 5/12.. Train loss: 1.386.. Valid loss: 1.008.. Valid accuracy: 0.696
# Epoch 5/12.. Train loss: 1.593.. Valid loss: 0.981.. Valid accuracy: 0.695
# Epoch 5/12.. Train loss: 1.357.. Valid loss: 1.028.. Valid accuracy: 0.692
# Epoch 5/12.. Train loss: 1.605.. Valid loss: 1.002.. Valid accuracy: 0.706
# Epoch 5/12.. Train loss: 1.641.. Valid loss: 1.002.. Valid accuracy: 0.712
# Epoch 5/12.. Train loss: 1.771.. Valid loss: 1.046.. Valid accuracy: 0.681
# Epoch 5/12.. Train loss: 1.770.. Valid loss: 0.981.. Valid accuracy: 0.717
# Epoch 5/12.. Train loss: 1.754.. Valid loss: 1.063.. Valid accuracy: 0.685
# Epoch 5/12.. Train loss: 1.511.. Valid loss: 1.013.. Valid accuracy: 0.702
# Epoch 5/12.. Train loss: 1.469.. Valid loss: 1.036.. Valid accuracy: 0.706
# Epoch 5/12.. Train loss: 1.746.. Valid loss: 1.150.. Valid accuracy: 0.660
# Epoch 5/12.. Train loss: 1.389.. Valid loss: 1.069.. Valid accuracy: 0.671
# Epoch 6/12.. Train loss: 1.582.. Valid loss: 1.052.. Valid accuracy: 0.681
# Epoch 6/12.. Train loss: 1.408.. Valid loss: 1.082.. Valid accuracy: 0.684
# Epoch 6/12.. Train loss: 1.578.. Valid loss: 1.103.. Valid accuracy: 0.671
# Epoch 6/12.. Train loss: 1.751.. Valid loss: 1.051.. Valid accuracy: 0.686
# Epoch 6/12.. Train loss: 1.411.. Valid loss: 1.093.. Valid accuracy: 0.693
# Epoch 6/12.. Train loss: 1.774.. Valid loss: 1.026.. Valid accuracy: 0.703
# Epoch 6/12.. Train loss: 1.561.. Valid loss: 1.050.. Valid accuracy: 0.692
# Epoch 6/12.. Train loss: 1.347.. Valid loss: 1.020.. Valid accuracy: 0.708
# Epoch 6/12.. Train loss: 1.421.. Valid loss: 1.020.. Valid accuracy: 0.706
# Epoch 6/12.. Train loss: 1.271.. Valid loss: 1.029.. Valid accuracy: 0.716
# Epoch 6/12.. Train loss: 1.535.. Valid loss: 0.941.. Valid accuracy: 0.717
# Epoch 6/12.. Train loss: 1.364.. Valid loss: 1.045.. Valid accuracy: 0.689
# Epoch 6/12.. Train loss: 1.445.. Valid loss: 0.971.. Valid accuracy: 0.717
# Epoch 6/12.. Train loss: 1.604.. Valid loss: 0.966.. Valid accuracy: 0.737
# Epoch 6/12.. Train loss: 1.427.. Valid loss: 0.974.. Valid accuracy: 0.712
# Epoch 6/12.. Train loss: 1.514.. Valid loss: 1.004.. Valid accuracy: 0.699
# Epoch 6/12.. Train loss: 1.564.. Valid loss: 1.005.. Valid accuracy: 0.706
# Epoch 6/12.. Train loss: 1.707.. Valid loss: 0.984.. Valid accuracy: 0.727
# Epoch 6/12.. Train loss: 1.678.. Valid loss: 0.967.. Valid accuracy: 0.726
# Epoch 6/12.. Train loss: 1.522.. Valid loss: 0.956.. Valid accuracy: 0.734
# Epoch 6/12.. Train loss: 1.503.. Valid loss: 1.031.. Valid accuracy: 0.705
# Epoch 6/12.. Train loss: 1.316.. Valid loss: 0.981.. Valid accuracy: 0.710
# Epoch 6/12.. Train loss: 1.707.. Valid loss: 0.966.. Valid accuracy: 0.696
# Epoch 6/12.. Train loss: 1.564.. Valid loss: 0.990.. Valid accuracy: 0.689
# Epoch 6/12.. Train loss: 1.176.. Valid loss: 0.960.. Valid accuracy: 0.701
# Epoch 6/12.. Train loss: 1.473.. Valid loss: 1.013.. Valid accuracy: 0.717
# Epoch 6/12.. Train loss: 1.556.. Valid loss: 1.041.. Valid accuracy: 0.710
# Epoch 6/12.. Train loss: 1.422.. Valid loss: 1.051.. Valid accuracy: 0.687
# Epoch 6/12.. Train loss: 1.551.. Valid loss: 0.916.. Valid accuracy: 0.746
# Epoch 6/12.. Train loss: 1.393.. Valid loss: 0.929.. Valid accuracy: 0.734
# Epoch 6/12.. Train loss: 1.635.. Valid loss: 0.921.. Valid accuracy: 0.721
# Epoch 6/12.. Train loss: 1.615.. Valid loss: 0.914.. Valid accuracy: 0.728
# Epoch 6/12.. Train loss: 1.500.. Valid loss: 0.894.. Valid accuracy: 0.740
# Epoch 6/12.. Train loss: 1.191.. Valid loss: 0.873.. Valid accuracy: 0.751
# Epoch 6/12.. Train loss: 1.407.. Valid loss: 0.976.. Valid accuracy: 0.721
# Epoch 6/12.. Train loss: 1.438.. Valid loss: 0.996.. Valid accuracy: 0.712
# Epoch 6/12.. Train loss: 1.262.. Valid loss: 0.999.. Valid accuracy: 0.711
# Epoch 6/12.. Train loss: 1.507.. Valid loss: 0.853.. Valid accuracy: 0.756
# Epoch 6/12.. Train loss: 1.456.. Valid loss: 0.911.. Valid accuracy: 0.744
# Epoch 6/12.. Train loss: 1.438.. Valid loss: 0.880.. Valid accuracy: 0.755
# Epoch 6/12.. Train loss: 1.418.. Valid loss: 0.875.. Valid accuracy: 0.748
# Epoch 7/12.. Train loss: 1.280.. Valid loss: 0.882.. Valid accuracy: 0.747
# Epoch 7/12.. Train loss: 1.412.. Valid loss: 1.030.. Valid accuracy: 0.693
# Epoch 7/12.. Train loss: 1.396.. Valid loss: 0.944.. Valid accuracy: 0.733
# Epoch 7/12.. Train loss: 1.382.. Valid loss: 0.955.. Valid accuracy: 0.723
# Epoch 7/12.. Train loss: 1.565.. Valid loss: 0.924.. Valid accuracy: 0.730
# Epoch 7/12.. Train loss: 1.302.. Valid loss: 0.893.. Valid accuracy: 0.740
# Epoch 7/12.. Train loss: 1.590.. Valid loss: 0.947.. Valid accuracy: 0.722
# Epoch 7/12.. Train loss: 1.381.. Valid loss: 0.963.. Valid accuracy: 0.710
# Epoch 7/12.. Train loss: 1.432.. Valid loss: 0.915.. Valid accuracy: 0.738
# Epoch 7/12.. Train loss: 1.289.. Valid loss: 0.888.. Valid accuracy: 0.750
# Epoch 7/12.. Train loss: 1.411.. Valid loss: 0.860.. Valid accuracy: 0.759
# Epoch 7/12.. Train loss: 1.758.. Valid loss: 0.895.. Valid accuracy: 0.742
# Epoch 7/12.. Train loss: 1.477.. Valid loss: 0.915.. Valid accuracy: 0.743
# Epoch 7/12.. Train loss: 1.454.. Valid loss: 0.840.. Valid accuracy: 0.758
# Epoch 7/12.. Train loss: 1.526.. Valid loss: 0.878.. Valid accuracy: 0.760
# Epoch 7/12.. Train loss: 1.250.. Valid loss: 0.970.. Valid accuracy: 0.715
# Epoch 7/12.. Train loss: 1.521.. Valid loss: 1.048.. Valid accuracy: 0.698
# Epoch 7/12.. Train loss: 1.388.. Valid loss: 0.895.. Valid accuracy: 0.745
# Epoch 7/12.. Train loss: 1.575.. Valid loss: 0.842.. Valid accuracy: 0.767
# Epoch 7/12.. Train loss: 1.273.. Valid loss: 0.820.. Valid accuracy: 0.778
# Epoch 7/12.. Train loss: 1.396.. Valid loss: 0.814.. Valid accuracy: 0.768
# Epoch 7/12.. Train loss: 1.363.. Valid loss: 0.838.. Valid accuracy: 0.767
# Epoch 7/12.. Train loss: 1.010.. Valid loss: 0.811.. Valid accuracy: 0.762
# Epoch 7/12.. Train loss: 1.440.. Valid loss: 0.812.. Valid accuracy: 0.758
# Epoch 7/12.. Train loss: 1.312.. Valid loss: 0.971.. Valid accuracy: 0.714
# Epoch 7/12.. Train loss: 1.614.. Valid loss: 0.930.. Valid accuracy: 0.725
# Epoch 7/12.. Train loss: 1.610.. Valid loss: 0.855.. Valid accuracy: 0.743
# Epoch 7/12.. Train loss: 1.322.. Valid loss: 0.904.. Valid accuracy: 0.728
# Epoch 7/12.. Train loss: 1.370.. Valid loss: 0.903.. Valid accuracy: 0.734
# Epoch 7/12.. Train loss: 1.575.. Valid loss: 0.824.. Valid accuracy: 0.756
# Epoch 7/12.. Train loss: 1.216.. Valid loss: 0.947.. Valid accuracy: 0.728
# Epoch 7/12.. Train loss: 1.238.. Valid loss: 0.974.. Valid accuracy: 0.722
# Epoch 7/12.. Train loss: 1.762.. Valid loss: 0.920.. Valid accuracy: 0.741
# Epoch 7/12.. Train loss: 1.436.. Valid loss: 0.900.. Valid accuracy: 0.752
# Epoch 7/12.. Train loss: 1.343.. Valid loss: 0.895.. Valid accuracy: 0.735
# Epoch 7/12.. Train loss: 1.347.. Valid loss: 0.822.. Valid accuracy: 0.760
# Epoch 7/12.. Train loss: 1.365.. Valid loss: 0.835.. Valid accuracy: 0.756
# Epoch 7/12.. Train loss: 1.743.. Valid loss: 0.880.. Valid accuracy: 0.746
# Epoch 7/12.. Train loss: 1.397.. Valid loss: 0.887.. Valid accuracy: 0.744
# Epoch 7/12.. Train loss: 1.459.. Valid loss: 0.919.. Valid accuracy: 0.732
# Epoch 7/12.. Train loss: 1.515.. Valid loss: 0.915.. Valid accuracy: 0.730
# Epoch 8/12.. Train loss: 1.365.. Valid loss: 0.915.. Valid accuracy: 0.726
# Epoch 8/12.. Train loss: 1.212.. Valid loss: 0.783.. Valid accuracy: 0.773
# Epoch 8/12.. Train loss: 1.077.. Valid loss: 0.841.. Valid accuracy: 0.753
# Epoch 8/12.. Train loss: 1.246.. Valid loss: 0.861.. Valid accuracy: 0.768
# Epoch 8/12.. Train loss: 1.378.. Valid loss: 0.826.. Valid accuracy: 0.769
# Epoch 8/12.. Train loss: 1.173.. Valid loss: 0.891.. Valid accuracy: 0.745
# Epoch 8/12.. Train loss: 1.414.. Valid loss: 0.799.. Valid accuracy: 0.771
# Epoch 8/12.. Train loss: 1.329.. Valid loss: 0.745.. Valid accuracy: 0.783
# Epoch 8/12.. Train loss: 1.000.. Valid loss: 0.808.. Valid accuracy: 0.781
# Epoch 8/12.. Train loss: 1.594.. Valid loss: 0.828.. Valid accuracy: 0.776
# Epoch 8/12.. Train loss: 1.155.. Valid loss: 0.832.. Valid accuracy: 0.756
# Epoch 8/12.. Train loss: 1.460.. Valid loss: 0.807.. Valid accuracy: 0.760
# Epoch 8/12.. Train loss: 1.440.. Valid loss: 0.814.. Valid accuracy: 0.769
# Epoch 8/12.. Train loss: 1.062.. Valid loss: 0.862.. Valid accuracy: 0.763
# Epoch 8/12.. Train loss: 1.429.. Valid loss: 0.847.. Valid accuracy: 0.761
# Epoch 8/12.. Train loss: 1.241.. Valid loss: 0.784.. Valid accuracy: 0.779
# Epoch 8/12.. Train loss: 1.233.. Valid loss: 0.801.. Valid accuracy: 0.787
# Epoch 8/12.. Train loss: 1.278.. Valid loss: 0.898.. Valid accuracy: 0.758
# Epoch 8/12.. Train loss: 1.465.. Valid loss: 0.740.. Valid accuracy: 0.804
# Epoch 8/12.. Train loss: 1.357.. Valid loss: 0.743.. Valid accuracy: 0.798
# Epoch 8/12.. Train loss: 1.238.. Valid loss: 0.769.. Valid accuracy: 0.783
# Epoch 8/12.. Train loss: 1.453.. Valid loss: 0.865.. Valid accuracy: 0.752
# Epoch 8/12.. Train loss: 1.475.. Valid loss: 0.834.. Valid accuracy: 0.764
# Epoch 8/12.. Train loss: 1.382.. Valid loss: 0.836.. Valid accuracy: 0.776
# Epoch 8/12.. Train loss: 1.342.. Valid loss: 0.839.. Valid accuracy: 0.773
# Epoch 8/12.. Train loss: 1.126.. Valid loss: 0.824.. Valid accuracy: 0.759
# Epoch 8/12.. Train loss: 1.436.. Valid loss: 0.874.. Valid accuracy: 0.759
# Epoch 8/12.. Train loss: 1.415.. Valid loss: 0.787.. Valid accuracy: 0.778
# Epoch 8/12.. Train loss: 1.311.. Valid loss: 0.755.. Valid accuracy: 0.791
# Epoch 8/12.. Train loss: 1.327.. Valid loss: 0.770.. Valid accuracy: 0.787
# Epoch 8/12.. Train loss: 1.447.. Valid loss: 0.785.. Valid accuracy: 0.784
# Epoch 8/12.. Train loss: 1.499.. Valid loss: 0.773.. Valid accuracy: 0.794
# Epoch 8/12.. Train loss: 1.398.. Valid loss: 0.791.. Valid accuracy: 0.780
# Epoch 8/12.. Train loss: 1.474.. Valid loss: 0.793.. Valid accuracy: 0.781
# Epoch 8/12.. Train loss: 1.275.. Valid loss: 0.902.. Valid accuracy: 0.732
# Epoch 8/12.. Train loss: 1.285.. Valid loss: 0.818.. Valid accuracy: 0.739
# Epoch 8/12.. Train loss: 1.430.. Valid loss: 0.775.. Valid accuracy: 0.765
# Epoch 8/12.. Train loss: 1.341.. Valid loss: 0.760.. Valid accuracy: 0.784
# Epoch 8/12.. Train loss: 1.016.. Valid loss: 0.834.. Valid accuracy: 0.750
# Epoch 8/12.. Train loss: 1.456.. Valid loss: 0.814.. Valid accuracy: 0.753
# Epoch 8/12.. Train loss: 1.371.. Valid loss: 0.798.. Valid accuracy: 0.769
# Epoch 9/12.. Train loss: 1.345.. Valid loss: 0.771.. Valid accuracy: 0.788
# Epoch 9/12.. Train loss: 1.406.. Valid loss: 0.835.. Valid accuracy: 0.765
# Epoch 9/12.. Train loss: 1.299.. Valid loss: 0.783.. Valid accuracy: 0.775
# Epoch 9/12.. Train loss: 1.368.. Valid loss: 0.771.. Valid accuracy: 0.784
# Epoch 9/12.. Train loss: 1.159.. Valid loss: 0.801.. Valid accuracy: 0.773
# Epoch 9/12.. Train loss: 1.078.. Valid loss: 0.825.. Valid accuracy: 0.763
# Epoch 9/12.. Train loss: 1.456.. Valid loss: 0.829.. Valid accuracy: 0.763
# Epoch 9/12.. Train loss: 1.348.. Valid loss: 0.757.. Valid accuracy: 0.787
# Epoch 9/12.. Train loss: 1.326.. Valid loss: 0.754.. Valid accuracy: 0.793
# Epoch 9/12.. Train loss: 1.354.. Valid loss: 0.773.. Valid accuracy: 0.773
# Epoch 9/12.. Train loss: 1.124.. Valid loss: 0.794.. Valid accuracy: 0.764
# Epoch 9/12.. Train loss: 1.271.. Valid loss: 0.790.. Valid accuracy: 0.769
# Epoch 9/12.. Train loss: 1.240.. Valid loss: 0.819.. Valid accuracy: 0.780
# Epoch 9/12.. Train loss: 1.078.. Valid loss: 0.737.. Valid accuracy: 0.785
# Epoch 9/12.. Train loss: 1.114.. Valid loss: 0.766.. Valid accuracy: 0.782
# Epoch 9/12.. Train loss: 1.186.. Valid loss: 0.730.. Valid accuracy: 0.786
# Epoch 9/12.. Train loss: 1.354.. Valid loss: 0.705.. Valid accuracy: 0.810
# Epoch 9/12.. Train loss: 1.362.. Valid loss: 0.724.. Valid accuracy: 0.809
# Epoch 9/12.. Train loss: 1.170.. Valid loss: 0.752.. Valid accuracy: 0.789
# Epoch 9/12.. Train loss: 1.083.. Valid loss: 0.797.. Valid accuracy: 0.771
# Epoch 9/12.. Train loss: 1.144.. Valid loss: 0.794.. Valid accuracy: 0.773
# Epoch 9/12.. Train loss: 0.994.. Valid loss: 0.790.. Valid accuracy: 0.778
# Epoch 9/12.. Train loss: 1.275.. Valid loss: 0.806.. Valid accuracy: 0.780
# Epoch 9/12.. Train loss: 1.264.. Valid loss: 0.809.. Valid accuracy: 0.765
# Epoch 9/12.. Train loss: 1.401.. Valid loss: 0.751.. Valid accuracy: 0.787
# Epoch 9/12.. Train loss: 1.100.. Valid loss: 0.755.. Valid accuracy: 0.790
# Epoch 9/12.. Train loss: 1.118.. Valid loss: 0.772.. Valid accuracy: 0.777
# Epoch 9/12.. Train loss: 1.372.. Valid loss: 0.764.. Valid accuracy: 0.778
# Epoch 9/12.. Train loss: 1.247.. Valid loss: 0.736.. Valid accuracy: 0.799
# Epoch 9/12.. Train loss: 1.465.. Valid loss: 0.864.. Valid accuracy: 0.764
# Epoch 9/12.. Train loss: 1.481.. Valid loss: 0.761.. Valid accuracy: 0.785
# Epoch 9/12.. Train loss: 1.039.. Valid loss: 0.694.. Valid accuracy: 0.818
# Epoch 9/12.. Train loss: 1.340.. Valid loss: 0.673.. Valid accuracy: 0.815
# Epoch 9/12.. Train loss: 1.117.. Valid loss: 0.676.. Valid accuracy: 0.808
# Epoch 9/12.. Train loss: 1.337.. Valid loss: 0.754.. Valid accuracy: 0.781
# Epoch 9/12.. Train loss: 1.235.. Valid loss: 0.839.. Valid accuracy: 0.753
# Epoch 9/12.. Train loss: 1.408.. Valid loss: 0.777.. Valid accuracy: 0.783
# Epoch 9/12.. Train loss: 1.398.. Valid loss: 0.722.. Valid accuracy: 0.793
# Epoch 9/12.. Train loss: 1.183.. Valid loss: 0.737.. Valid accuracy: 0.787
# Epoch 9/12.. Train loss: 1.281.. Valid loss: 0.747.. Valid accuracy: 0.783
# Epoch 9/12.. Train loss: 1.359.. Valid loss: 0.769.. Valid accuracy: 0.789
# Epoch 10/12.. Train loss: 1.136.. Valid loss: 0.727.. Valid accuracy: 0.801
# Epoch 10/12.. Train loss: 1.151.. Valid loss: 0.751.. Valid accuracy: 0.810
# Epoch 10/12.. Train loss: 1.418.. Valid loss: 0.799.. Valid accuracy: 0.787
# Epoch 10/12.. Train loss: 1.095.. Valid loss: 0.754.. Valid accuracy: 0.791
# Epoch 10/12.. Train loss: 1.269.. Valid loss: 0.709.. Valid accuracy: 0.804
# Epoch 10/12.. Train loss: 1.296.. Valid loss: 0.697.. Valid accuracy: 0.803
# Epoch 10/12.. Train loss: 1.197.. Valid loss: 0.770.. Valid accuracy: 0.788
# Epoch 10/12.. Train loss: 1.388.. Valid loss: 0.759.. Valid accuracy: 0.799
# Epoch 10/12.. Train loss: 1.337.. Valid loss: 0.712.. Valid accuracy: 0.804
# Epoch 10/12.. Train loss: 1.243.. Valid loss: 0.714.. Valid accuracy: 0.808
# Epoch 10/12.. Train loss: 1.142.. Valid loss: 0.757.. Valid accuracy: 0.793
# Epoch 10/12.. Train loss: 1.206.. Valid loss: 0.745.. Valid accuracy: 0.782
# Epoch 10/12.. Train loss: 1.242.. Valid loss: 0.752.. Valid accuracy: 0.790
# Epoch 10/12.. Train loss: 1.356.. Valid loss: 0.672.. Valid accuracy: 0.823
# Epoch 10/12.. Train loss: 1.218.. Valid loss: 0.755.. Valid accuracy: 0.787
# Epoch 10/12.. Train loss: 1.196.. Valid loss: 0.733.. Valid accuracy: 0.794
# Epoch 10/12.. Train loss: 1.048.. Valid loss: 0.730.. Valid accuracy: 0.792
# Epoch 10/12.. Train loss: 0.991.. Valid loss: 0.686.. Valid accuracy: 0.809
# Epoch 10/12.. Train loss: 1.042.. Valid loss: 0.689.. Valid accuracy: 0.802
# Epoch 10/12.. Train loss: 1.023.. Valid loss: 0.712.. Valid accuracy: 0.796
# Epoch 10/12.. Train loss: 1.298.. Valid loss: 0.734.. Valid accuracy: 0.800
# Epoch 10/12.. Train loss: 1.241.. Valid loss: 0.733.. Valid accuracy: 0.785
# Epoch 10/12.. Train loss: 1.371.. Valid loss: 0.746.. Valid accuracy: 0.795
# Epoch 10/12.. Train loss: 1.101.. Valid loss: 0.760.. Valid accuracy: 0.787
# Epoch 10/12.. Train loss: 1.088.. Valid loss: 0.761.. Valid accuracy: 0.783
# Epoch 10/12.. Train loss: 1.398.. Valid loss: 0.747.. Valid accuracy: 0.795
# Epoch 10/12.. Train loss: 1.337.. Valid loss: 0.733.. Valid accuracy: 0.798
# Epoch 10/12.. Train loss: 1.214.. Valid loss: 0.758.. Valid accuracy: 0.795
# Epoch 10/12.. Train loss: 0.958.. Valid loss: 0.782.. Valid accuracy: 0.786
# Epoch 10/12.. Train loss: 1.539.. Valid loss: 0.742.. Valid accuracy: 0.799
# Epoch 10/12.. Train loss: 1.240.. Valid loss: 0.779.. Valid accuracy: 0.763
# Epoch 10/12.. Train loss: 0.987.. Valid loss: 0.773.. Valid accuracy: 0.776
# Epoch 10/12.. Train loss: 1.302.. Valid loss: 0.698.. Valid accuracy: 0.798
# Epoch 10/12.. Train loss: 1.147.. Valid loss: 0.826.. Valid accuracy: 0.756
# Epoch 10/12.. Train loss: 1.434.. Valid loss: 0.752.. Valid accuracy: 0.791
# Epoch 10/12.. Train loss: 1.225.. Valid loss: 0.688.. Valid accuracy: 0.809
# Epoch 10/12.. Train loss: 1.245.. Valid loss: 0.693.. Valid accuracy: 0.799
# Epoch 10/12.. Train loss: 1.514.. Valid loss: 0.663.. Valid accuracy: 0.805
# Epoch 10/12.. Train loss: 1.180.. Valid loss: 0.668.. Valid accuracy: 0.802
# Epoch 10/12.. Train loss: 1.269.. Valid loss: 0.678.. Valid accuracy: 0.818
# Epoch 10/12.. Train loss: 1.135.. Valid loss: 0.719.. Valid accuracy: 0.804
# Epoch 11/12.. Train loss: 1.156.. Valid loss: 0.712.. Valid accuracy: 0.789
# Epoch 11/12.. Train loss: 1.365.. Valid loss: 0.676.. Valid accuracy: 0.806
# Epoch 11/12.. Train loss: 1.212.. Valid loss: 0.642.. Valid accuracy: 0.823
# Epoch 11/12.. Train loss: 1.010.. Valid loss: 0.660.. Valid accuracy: 0.805
# Epoch 11/12.. Train loss: 0.970.. Valid loss: 0.652.. Valid accuracy: 0.800
# Epoch 11/12.. Train loss: 1.030.. Valid loss: 0.654.. Valid accuracy: 0.802
# Epoch 11/12.. Train loss: 1.308.. Valid loss: 0.670.. Valid accuracy: 0.800
# Epoch 11/12.. Train loss: 1.316.. Valid loss: 0.686.. Valid accuracy: 0.798
# Epoch 11/12.. Train loss: 1.112.. Valid loss: 0.686.. Valid accuracy: 0.806
# Epoch 11/12.. Train loss: 1.122.. Valid loss: 0.642.. Valid accuracy: 0.815
# Epoch 11/12.. Train loss: 0.925.. Valid loss: 0.652.. Valid accuracy: 0.816
# Epoch 11/12.. Train loss: 1.081.. Valid loss: 0.630.. Valid accuracy: 0.815
# Epoch 11/12.. Train loss: 1.095.. Valid loss: 0.617.. Valid accuracy: 0.822
# Epoch 11/12.. Train loss: 1.175.. Valid loss: 0.611.. Valid accuracy: 0.828
# Epoch 11/12.. Train loss: 1.272.. Valid loss: 0.612.. Valid accuracy: 0.823
# Epoch 11/12.. Train loss: 1.078.. Valid loss: 0.648.. Valid accuracy: 0.832
# Epoch 11/12.. Train loss: 1.276.. Valid loss: 0.692.. Valid accuracy: 0.810
# Epoch 11/12.. Train loss: 1.207.. Valid loss: 0.647.. Valid accuracy: 0.821
# Epoch 11/12.. Train loss: 0.870.. Valid loss: 0.700.. Valid accuracy: 0.812
# Epoch 11/12.. Train loss: 1.365.. Valid loss: 0.701.. Valid accuracy: 0.813
# Epoch 11/12.. Train loss: 1.194.. Valid loss: 0.694.. Valid accuracy: 0.800
# Epoch 11/12.. Train loss: 1.167.. Valid loss: 0.685.. Valid accuracy: 0.802
# Epoch 11/12.. Train loss: 0.994.. Valid loss: 0.663.. Valid accuracy: 0.809
# Epoch 11/12.. Train loss: 1.336.. Valid loss: 0.657.. Valid accuracy: 0.808
# Epoch 11/12.. Train loss: 1.210.. Valid loss: 0.661.. Valid accuracy: 0.813
# Epoch 11/12.. Train loss: 1.227.. Valid loss: 0.705.. Valid accuracy: 0.794
# Epoch 11/12.. Train loss: 1.088.. Valid loss: 0.710.. Valid accuracy: 0.787
# Epoch 11/12.. Train loss: 1.061.. Valid loss: 0.662.. Valid accuracy: 0.811
# Epoch 11/12.. Train loss: 1.389.. Valid loss: 0.667.. Valid accuracy: 0.816
# Epoch 11/12.. Train loss: 1.250.. Valid loss: 0.662.. Valid accuracy: 0.831
# Epoch 11/12.. Train loss: 1.250.. Valid loss: 0.654.. Valid accuracy: 0.821
# Epoch 11/12.. Train loss: 1.249.. Valid loss: 0.669.. Valid accuracy: 0.818
# Epoch 11/12.. Train loss: 1.110.. Valid loss: 0.682.. Valid accuracy: 0.809
# Epoch 11/12.. Train loss: 1.423.. Valid loss: 0.704.. Valid accuracy: 0.811
# Epoch 11/12.. Train loss: 1.489.. Valid loss: 0.696.. Valid accuracy: 0.802
# Epoch 11/12.. Train loss: 1.253.. Valid loss: 0.761.. Valid accuracy: 0.798
# Epoch 11/12.. Train loss: 1.082.. Valid loss: 0.737.. Valid accuracy: 0.806
# Epoch 11/12.. Train loss: 1.269.. Valid loss: 0.718.. Valid accuracy: 0.809
# Epoch 11/12.. Train loss: 1.361.. Valid loss: 0.715.. Valid accuracy: 0.821
# Epoch 11/12.. Train loss: 1.286.. Valid loss: 0.769.. Valid accuracy: 0.795
# Epoch 11/12.. Train loss: 1.224.. Valid loss: 0.747.. Valid accuracy: 0.798
# Epoch 12/12.. Train loss: 1.256.. Valid loss: 0.723.. Valid accuracy: 0.806
# Epoch 12/12.. Train loss: 1.189.. Valid loss: 0.717.. Valid accuracy: 0.798
# Epoch 12/12.. Train loss: 1.222.. Valid loss: 0.675.. Valid accuracy: 0.815
# Epoch 12/12.. Train loss: 1.193.. Valid loss: 0.716.. Valid accuracy: 0.805
# Epoch 12/12.. Train loss: 1.240.. Valid loss: 0.731.. Valid accuracy: 0.796
# Epoch 12/12.. Train loss: 1.021.. Valid loss: 0.681.. Valid accuracy: 0.802
# Epoch 12/12.. Train loss: 0.979.. Valid loss: 0.695.. Valid accuracy: 0.812
# Epoch 12/12.. Train loss: 1.079.. Valid loss: 0.682.. Valid accuracy: 0.811
# Epoch 12/12.. Train loss: 1.193.. Valid loss: 0.689.. Valid accuracy: 0.803
# Epoch 12/12.. Train loss: 1.146.. Valid loss: 0.664.. Valid accuracy: 0.816
# Epoch 12/12.. Train loss: 1.069.. Valid loss: 0.685.. Valid accuracy: 0.815
# Epoch 12/12.. Train loss: 1.336.. Valid loss: 0.678.. Valid accuracy: 0.811
# Epoch 12/12.. Train loss: 1.229.. Valid loss: 0.668.. Valid accuracy: 0.808
# Epoch 12/12.. Train loss: 1.280.. Valid loss: 0.649.. Valid accuracy: 0.811
# Epoch 12/12.. Train loss: 1.230.. Valid loss: 0.703.. Valid accuracy: 0.799
# Epoch 12/12.. Train loss: 1.220.. Valid loss: 0.655.. Valid accuracy: 0.819
# Epoch 12/12.. Train loss: 1.192.. Valid loss: 0.648.. Valid accuracy: 0.824
# Epoch 12/12.. Train loss: 1.043.. Valid loss: 0.670.. Valid accuracy: 0.817
# Epoch 12/12.. Train loss: 1.182.. Valid loss: 0.643.. Valid accuracy: 0.833
# Epoch 12/12.. Train loss: 0.987.. Valid loss: 0.655.. Valid accuracy: 0.807
# Epoch 12/12.. Train loss: 1.022.. Valid loss: 0.673.. Valid accuracy: 0.807
# Epoch 12/12.. Train loss: 1.117.. Valid loss: 0.724.. Valid accuracy: 0.805
# Epoch 12/12.. Train loss: 1.159.. Valid loss: 0.619.. Valid accuracy: 0.827
# Epoch 12/12.. Train loss: 0.789.. Valid loss: 0.602.. Valid accuracy: 0.831
# Epoch 12/12.. Train loss: 1.362.. Valid loss: 0.631.. Valid accuracy: 0.825
# Epoch 12/12.. Train loss: 1.173.. Valid loss: 0.715.. Valid accuracy: 0.799
# Epoch 12/12.. Train loss: 1.229.. Valid loss: 0.697.. Valid accuracy: 0.805
# Epoch 12/12.. Train loss: 1.237.. Valid loss: 0.714.. Valid accuracy: 0.784
# Epoch 12/12.. Train loss: 1.052.. Valid loss: 0.712.. Valid accuracy: 0.807
# Epoch 12/12.. Train loss: 1.244.. Valid loss: 0.663.. Valid accuracy: 0.823
# Epoch 12/12.. Train loss: 1.089.. Valid loss: 0.646.. Valid accuracy: 0.815
# Epoch 12/12.. Train loss: 1.290.. Valid loss: 0.744.. Valid accuracy: 0.791
# Epoch 12/12.. Train loss: 1.475.. Valid loss: 0.705.. Valid accuracy: 0.801
# Epoch 12/12.. Train loss: 1.208.. Valid loss: 0.696.. Valid accuracy: 0.804
# Epoch 12/12.. Train loss: 1.350.. Valid loss: 0.715.. Valid accuracy: 0.801
# Epoch 12/12.. Train loss: 1.354.. Valid loss: 0.672.. Valid accuracy: 0.820
# Epoch 12/12.. Train loss: 1.231.. Valid loss: 0.644.. Valid accuracy: 0.820
# Epoch 12/12.. Train loss: 1.039.. Valid loss: 0.628.. Valid accuracy: 0.831
# Epoch 12/12.. Train loss: 1.200.. Valid loss: 0.590.. Valid accuracy: 0.839
# Epoch 12/12.. Train loss: 1.480.. Valid loss: 0.577.. Valid accuracy: 0.837
# Epoch 12/12.. Train loss: 1.220.. Valid loss: 0.639.. Valid accuracy: 0.822

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
correct = 0
total = 0
model.to('cuda:0')
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to('cuda'), labels.to('cuda')
        outputs = model(images)
        x, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the test images: %d %%' % (100 * correct / total))
# Out:
# Accuracy of the network on the test images: 70 %

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = train_dataset.class_to_idx
model.cpu
torch.save({'structure' :'densenet121',
            'hidden_layer1':256,
            'state_dict':model.state_dict(),
            'class_to_idx':model.class_to_idx},
            'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_model(path):
    checkpoint = torch.load('checkpoint.pth')
    structure = checkpoint['structure']
    hidden_layer1 = checkpoint['hidden_layer1']
    model, first_layer = model_setup()
    
    for param in model.parameters():
        param.requires_grad = False
    
    model.classifier = nn.Sequential(nn.Linear(first_layer, 256),
                                     nn.ReLU(),
                                     nn.Dropout(0.2),
                                     nn.Linear(256, 90),
                                     nn.ReLU(),
                                     nn.Linear(90, 80),
                                     nn.ReLU(),
                                     nn.Linear(80, 102),
                                     nn.LogSoftmax(dim=1))

    criterion = nn.NLLLoss()
    optimizer = optim.Adam(model.classifier.parameters(), lr=0.003)
    model.cuda()


    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    return model
    
    
model = load_model('checkpoint.pth')  
print(model)
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1024, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=256, out_features=90, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=90, out_features=80, bias=True)
#     (6): ReLU()
#     (7): Linear(in_features=80, out_features=102, bias=True)
#     (8): LogSoftmax(dim=1)
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
# TODO: Process a PIL image for use in a PyTorch model
def process_image(image):
    img_pil = Image.open(image)
   
    transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    return transform(img_pil)

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    if ax is None:
        fig, ax = plt.subplots()
    image = image.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

imshow(process_image("flowers/test/10/image_07090.jpg"))
# Out:
# <Axes: >

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
model.class_to_idx =train_dataset.class_to_idx

ctx = model.class_to_idx

def predict(image_path, model, topk = 5):
    model.to('cuda:0')
    img_torch = process_image(image_path)
    img_torch = img_torch.unsqueeze_(0)
    img_torch = img_torch.float()
    
    with torch.no_grad():
        output = model.forward(img_torch.cuda())
        
    probability = F.softmax(output.data,dim=1)
    
    return probability.topk(topk)
    

    # TODO: Implement the code to predict the class from an image file

# %%
image_pth = 'flowers/test/16/image_06670.jpg'
probs, classes = predict(image_pth, model)

class_to_idx_inverted = {model.class_to_idx[k]: k for k in model.class_to_idx}
classes = [class_to_idx_inverted[i] for i in classes.cpu().numpy()[0]]
probs = probs.cpu().numpy()[0]

# probabilities and classes
print(probs) 
print(classes)
# Out:
# [0.0305367  0.0291648  0.02758917 0.02505663 0.023812  ]
# ['40', '45', '62', '84', '3']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
flower_classes = [cat_to_name[j] for j in classes]

img = Image.open("flowers/test/1/image_06743.jpg")

plt.figure(figsize = [5, 10])
ax1 = plt.subplot(2, 1, 1)
ax1.set_axis_off()
ax1.set_title(flower_classes[0])
ax1.imshow(img)

ax2 = plt.subplot(2, 1, 2)
y_pos = np.arange(5)
ax2.set_yticks(y_pos)
ax2.set_yticklabels(flower_classes)
ax2.invert_yaxis()
ax2.set_xlabel('Probability')
plt.barh(y_pos, probs)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Reminder for Workspace users
# If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.
